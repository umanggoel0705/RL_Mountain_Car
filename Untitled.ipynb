# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Using cached pygame-2.6.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Using cached pygame-2.6.1-cp312-cp312-win_amd64.whl (10.6 MB)
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1

# %%
# !pip install --upgrade gym numpy
# Out:
# Requirement already satisfied: gym in c:\users\umang\miniconda3\envs\mountain_car\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy in c:\users\umang\miniconda3\envs\mountain_car\lib\site-packages (2.2.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\umang\miniconda3\envs\mountain_car\lib\site-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\users\umang\miniconda3\envs\mountain_car\lib\site-packages (from gym) (0.0.8)

# %%
import numpy as np
if not hasattr(np, 'bool8'):
    np.bool8 = np.bool_

# %%
import gymnasium as gym
import os
from stable_baselines3 import PPO
from stable_baselines3.common. vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Understanding the Environment

# %%
watch_env = gym.make("MountainCar-v0", render_mode='human')

# %%
watch_env.action_space
# Out:
# Discrete(3)

# %%
watch_env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
episodes = 5
for episode in range(episodes):
    state, _ = watch_env.reset()
    done = False
    truncate = False
    score = 0

    while not done and not truncate:
        action = watch_env.action_space.sample()
        n_state, reward, done, truncate, info = watch_env.step(action)
        score += reward
    print(f"Episode:{episode+1} Score:{score}")
watch_env.close()
# Out:
# Episode:1 Score:-200.0
# Episode:2 Score:-200.0
# Episode:3 Score:-200.0
# Episode:4 Score:-200.0
# Episode:5 Score:-200.0

# %% [markdown]
# ### Training the RL Model

# %%
env = gym.make("MountainCar-v0")
env = DummyVecEnv([lambda : env])
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=250000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2160 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1409        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010163624 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0005      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00423    |
# |    value_loss           | 134         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1268         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0067111496 |
# |    clip_fraction        | 0.00732      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0626      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 90.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1211         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0015843217 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0161      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000155    |
# |    value_loss           | 84.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009362394 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 69.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011604624 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -5.6e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.88        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00476    |
# |    value_loss           | 54.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013237433 |
# |    clip_fraction        | 0.0364      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00117     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.33        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 42          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1175         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0055640293 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | -0.000571    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.02         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 30.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1156        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002378226 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.00337     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 21.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1146         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0069121253 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.00151     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.619        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 14.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1124         |
# |    iterations           | 11           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0003562721 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.000673     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.351        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00114      |
# |    value_loss           | 9.35         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1106         |
# |    iterations           | 12           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0038690139 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000812     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.514        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000276    |
# |    value_loss           | 5.81         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1090       |
# |    iterations           | 13         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01397589 |
# |    clip_fraction        | 0.0146     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.05      |
# |    explained_variance   | -0.00112   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.328      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00106   |
# |    value_loss           | 3.73       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 14           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0023242317 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -6.4e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.219        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000805    |
# |    value_loss           | 2.4          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009322243 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00132    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1055        |
# |    iterations           | 16          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007974523 |
# |    clip_fraction        | 0.00469     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.00146    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0753      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000749   |
# |    value_loss           | 0.946       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 17          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008450274 |
# |    clip_fraction        | 0.0189      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.000388   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.121       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 0.576       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1018        |
# |    iterations           | 18          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015396172 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.00275    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0606      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 0.385       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1011        |
# |    iterations           | 19          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010670813 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.000379   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0461      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 0.241       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1004         |
# |    iterations           | 20           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0030170088 |
# |    clip_fraction        | 0.00166      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.00138     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0156       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00027     |
# |    value_loss           | 0.158        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 21          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013919902 |
# |    clip_fraction        | 0.0226      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00308    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0581      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 0.102       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1001         |
# |    iterations           | 22           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0063948585 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | -0.00185     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0258       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 0.0666       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1007         |
# |    iterations           | 23           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0100139985 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.889       |
# |    explained_variance   | -0.00313     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00494      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000746    |
# |    value_loss           | 0.0455       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1008        |
# |    iterations           | 24          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009247979 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | -0.0045     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00869    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00358    |
# |    value_loss           | 0.0296      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 25          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005519339 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.862      |
# |    explained_variance   | -0.00133    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 0.0195      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 26          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008331459 |
# |    clip_fraction        | 0.0117      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.801      |
# |    explained_variance   | -0.00115    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000144   |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1016         |
# |    iterations           | 27           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0038805036 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | -0.00559     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000218    |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000823    |
# |    value_loss           | 0.0092       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1010        |
# |    iterations           | 28          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004589616 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.842      |
# |    explained_variance   | -0.00397    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00468     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00391    |
# |    value_loss           | 0.00628     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1011         |
# |    iterations           | 29           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0050137467 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.893       |
# |    explained_variance   | -0.00633     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00784     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 0.00432      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1015         |
# |    iterations           | 30           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0076235784 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.952       |
# |    explained_variance   | -0.00277     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000922     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 0.00298      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1019        |
# |    iterations           | 31          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005360515 |
# |    clip_fraction        | 0.00249     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | -0.00665    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00323     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 0.00218     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1019        |
# |    iterations           | 32          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009606036 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.00433    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0368      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 0.0015      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1015        |
# |    iterations           | 33          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008028242 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.00276    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0265     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000345   |
# |    value_loss           | 0.00103     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1005         |
# |    iterations           | 34           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0064045535 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | -0.00733     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0065       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 0.00076      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 35           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0016571106 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.954       |
# |    explained_variance   | -0.0027      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00105      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000356     |
# |    value_loss           | 0.000564     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 975          |
# |    iterations           | 36           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0122728245 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.00327      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0032      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00323     |
# |    value_loss           | 0.00039      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 972        |
# |    iterations           | 37         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00642683 |
# |    clip_fraction        | 0.0558     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.921     |
# |    explained_variance   | -0.00843   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00224   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00809   |
# |    value_loss           | 0.000287   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 38           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0043695928 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | -0.0141      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0108       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 2.97e-05     |
# |    value_loss           | 0.000202     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 39           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0073963962 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | -0.0194      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0134      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 0.000155     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 40           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0098048765 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.0107      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00714      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00677     |
# |    value_loss           | 0.000111     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 41          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010219282 |
# |    clip_fraction        | 0.013       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.0159     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0156      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 7.82e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 42          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013511404 |
# |    clip_fraction        | 0.00669     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0166     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0471     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 5.71e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 43          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009467734 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.0599     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0205     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 4.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 44          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016556583 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | -0.0261     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 2.87e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 45           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0044354117 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.933       |
# |    explained_variance   | -0.0601      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00166     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 2.02e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 46          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009163679 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.857      |
# |    explained_variance   | -0.0647     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0147      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 1.43e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 47          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007854461 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | -0.0529     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0165     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00071    |
# |    value_loss           | 1.02e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 48          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006582637 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | -0.0617     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0302      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000498   |
# |    value_loss           | 7.4e-06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 49          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.001096464 |
# |    clip_fraction        | 0.00913     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | -0.161      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00798     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000331   |
# |    value_loss           | 5.6e-06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 50           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0041778833 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | -0.107       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 4.08e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 51           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0047261887 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | -0.154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000473     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 3.07e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 52           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0032389504 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | -0.132       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00829     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000914    |
# |    value_loss           | 2.22e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 53           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0032458215 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | -0.0268      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00333     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 1.65e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 54           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0036252667 |
# |    clip_fraction        | 0.0491       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.671       |
# |    explained_variance   | -0.323       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00386      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 1.32e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 55           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0029801694 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.729       |
# |    explained_variance   | -0.202       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00459     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 9.86e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 943         |
# |    iterations           | 56          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.004270969 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | -0.171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 6.82e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 57           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0026623164 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | -0.217       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.014        |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 5.59e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 938          |
# |    iterations           | 58           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0038343407 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.761       |
# |    explained_variance   | -0.684       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.019       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 5.44e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 59           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0057773925 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | -0.435       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.016       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00465     |
# |    value_loss           | 4.51e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 60          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.004445223 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | -0.85       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -8.32e-05   |
# |    value_loss           | 4.75e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 940          |
# |    iterations           | 61           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0046957033 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.792       |
# |    explained_variance   | -0.186       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0109      |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 3.62e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 62          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.006859772 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | -1.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.017      |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 5.73e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 941          |
# |    iterations           | 63           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0042480924 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.885       |
# |    explained_variance   | -0.756       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00354      |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 6.18e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 64          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008440466 |
# |    clip_fraction        | 0.0325      |
# ...
# |    iterations           | 103          |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 210944       |
# | train/                  |              |
# |    approx_kl            | 0.0013486424 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.191       |
# |    explained_variance   | -2.02        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0199      |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 1.58e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 104          |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0021619704 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | -1.93        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00414     |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 1.07e-06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 950           |
# |    iterations           | 105           |
# |    time_elapsed         | 226           |
# |    total_timesteps      | 215040        |
# | train/                  |               |
# |    approx_kl            | 0.00051597226 |
# |    clip_fraction        | 0.00327       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.196        |
# |    explained_variance   | -1.61         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00924      |
# |    n_updates            | 1040          |
# |    policy_gradient_loss | -0.000315     |
# |    value_loss           | 3.73e-07      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 106         |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.004356336 |
# |    clip_fraction        | 0.0185      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.244      |
# |    explained_variance   | -1.82       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0266      |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 1.48e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 107         |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 219136      |
# | train/                  |             |
# |    approx_kl            | 0.001060108 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | -1.49       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0329      |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.000548   |
# |    value_loss           | 4.62e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 108          |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0011514876 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.175       |
# |    explained_variance   | -1.75        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00689      |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 7.74e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 109          |
# |    time_elapsed         | 234          |
# |    total_timesteps      | 223232       |
# | train/                  |              |
# |    approx_kl            | 0.0018075709 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | -1.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00877      |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.0059      |
# |    value_loss           | 5.18e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 110          |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0013084419 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | -2.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0226      |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 2.79e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 111          |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 227328       |
# | train/                  |              |
# |    approx_kl            | 0.0011886362 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | -1.8         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0129      |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 2.45e-07     |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 949       |
# |    iterations           | 112       |
# |    time_elapsed         | 241       |
# |    total_timesteps      | 229376    |
# | train/                  |           |
# |    approx_kl            | 0.0018368 |
# |    clip_fraction        | 0.0165    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.166    |
# |    explained_variance   | -1.54     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00169  |
# |    n_updates            | 1110      |
# |    policy_gradient_loss | -0.00252  |
# |    value_loss           | 6.01e-07  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 113          |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 231424       |
# | train/                  |              |
# |    approx_kl            | 0.0011151644 |
# |    clip_fraction        | 0.0107       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.178       |
# |    explained_variance   | -1.5         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00272      |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | -0.000196    |
# |    value_loss           | 1.49e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 114         |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.006107688 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | -2.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 3.61e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 115          |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0005423831 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -1.92        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0036       |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 7.55e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 116         |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 237568      |
# | train/                  |             |
# |    approx_kl            | 0.002769759 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.203      |
# |    explained_variance   | -1.42       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00572    |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 1.9e-06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 944         |
# |    iterations           | 117         |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 239616      |
# | train/                  |             |
# |    approx_kl            | 0.002590675 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | -1.83       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0222     |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.00789    |
# |    value_loss           | 8e-07       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 118          |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 241664       |
# | train/                  |              |
# |    approx_kl            | 0.0010323974 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | -1.66        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00314      |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 4.44e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 119          |
# |    time_elapsed         | 258          |
# |    total_timesteps      | 243712       |
# | train/                  |              |
# |    approx_kl            | 0.0027491825 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -1.32        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00231      |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 2.55e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 120          |
# |    time_elapsed         | 260          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0005990767 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | -1.95        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000599     |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.000942    |
# |    value_loss           | 6.32e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 121          |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 247808       |
# | train/                  |              |
# |    approx_kl            | 0.0013359761 |
# |    clip_fraction        | 0.00815      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.202       |
# |    explained_variance   | -1.41        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00669      |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 1.34e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 122          |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0009975412 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.201       |
# |    explained_variance   | -1.5         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00381     |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 3.22e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 123          |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 251904       |
# | train/                  |              |
# |    approx_kl            | 0.0018854307 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -1.77        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0103      |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 4.67e-07     |
# ------------------------------------------

# %%
PPO_path = os.path.join('Saved Model', 'PPO_2.5L')
model.save(PPO_path)

# %% [markdown]
# ### Evaluate Model

# %%
eval_env = gym.make("MountainCar-v0", render_mode='human')
evaluate_policy(model, eval_env, n_eval_episodes=5, render=True)
eval_env.close()

# %% [markdown]
# ### Test the Model

# %%
test_env = gym.make("MountainCar-v0", render_mode='human')
episodes = 5
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncate = False
    score = 0

    while not done and not truncate:
        action, _ = model.predict(obs)
        obs, reward, done, truncate, info = test_env.step(action)
        score += reward
    print(f"Episode:{episode+1} Score:{score}")
test_env.close()
# Out:
# Episode:1 Score:-200.0
# Episode:2 Score:-200.0
# Episode:3 Score:-200.0
# Episode:4 Score:-200.0
# Episode:5 Score:-200.0

# %% [markdown]
# ### Alteranate Algos

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=1000000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2045     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1985     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00351  |
# |    n_updates        | 374      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1957     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.56e-05 |
# |    n_updates        | 574      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1903     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000129 |
# |    n_updates        | 774      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1877     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000101 |
# |    n_updates        | 974      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1820     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.23e-05 |
# |    n_updates        | 1174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1741     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.87e-05 |
# |    n_updates        | 1374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1764     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3e-05    |
# |    n_updates        | 1574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1778     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37e-05 |
# |    n_updates        | 1774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1781     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4e-06  |
# |    n_updates        | 1974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1782     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04e-06 |
# |    n_updates        | 2174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1794     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 9600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.11e-07 |
# |    n_updates        | 2374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1798     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000612 |
# |    n_updates        | 2574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1789     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 11200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000361 |
# |    n_updates        | 2774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1779     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000403 |
# |    n_updates        | 2974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1780     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 12800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000397 |
# |    n_updates        | 3174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1780     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00023  |
# |    n_updates        | 3374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1787     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 14400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000136 |
# |    n_updates        | 3574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1787     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 15200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000256 |
# |    n_updates        | 3774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1791     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000167 |
# |    n_updates        | 3974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1799     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 16800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000159 |
# |    n_updates        | 4174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1801     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000138 |
# |    n_updates        | 4374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1807     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 18400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000145 |
# |    n_updates        | 4574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1807     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.7e-05  |
# |    n_updates        | 4774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1807     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.32e-05 |
# |    n_updates        | 4974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1805     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 20800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000215 |
# |    n_updates        | 5174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1807     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 21600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.46e-05 |
# |    n_updates        | 5374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1810     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 22400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000134 |
# |    n_updates        | 5574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1814     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 23200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-05 |
# |    n_updates        | 5774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1810     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000111 |
# |    n_updates        | 5974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.764    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1810     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 24800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.89e-05 |
# |    n_updates        | 6174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.757    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1812     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 25600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.25e-05 |
# |    n_updates        | 6374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.749    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1811     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 26400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.58e-05 |
# |    n_updates        | 6574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1814     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 27200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.95e-05 |
# |    n_updates        | 6774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1812     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91e-05 |
# |    n_updates        | 6974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1813     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 28800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.45e-05 |
# |    n_updates        | 7174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1812     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 29600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87e-05 |
# |    n_updates        | 7374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1805     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 30400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000207 |
# |    n_updates        | 7574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1791     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 31200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000112 |
# |    n_updates        | 7774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1766     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.55e-05 |
# |    n_updates        | 7974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1749     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 32800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.26e-05 |
# |    n_updates        | 8174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1736     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 33600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.24e-05 |
# |    n_updates        | 8374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1727     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 34400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.32e-05 |
# |    n_updates        | 8574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1721     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 35200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.37e-05 |
# |    n_updates        | 8774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1705     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.61e-05 |
# |    n_updates        | 8974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1703     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 36800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35e-05 |
# |    n_updates        | 9174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.643    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1703     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 37600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21e-05 |
# |    n_updates        | 9374     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.635    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1700     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 38400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.04e-05 |
# |    n_updates        | 9574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1698     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 39200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.14e-06 |
# |    n_updates        | 9774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1697     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27e-05 |
# |    n_updates        | 9974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1697     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 40800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000125 |
# |    n_updates        | 10174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1698     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 41600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.77e-05 |
# |    n_updates        | 10374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1698     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 42400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000168 |
# |    n_updates        | 10574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1695     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 43200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.3e-05  |
# |    n_updates        | 10774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1693     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.69e-05 |
# |    n_updates        | 10974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1692     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 44800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.62e-05 |
# |    n_updates        | 11174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1693     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 45600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.05e-05 |
# |    n_updates        | 11374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1692     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 46400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.34e-05 |
# |    n_updates        | 11574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1691     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 47200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61e-05 |
# |    n_updates        | 11774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1689     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09e-05 |
# |    n_updates        | 11974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1690     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 48800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54e-05 |
# |    n_updates        | 12174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.529    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1688     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 49600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12e-05 |
# |    n_updates        | 12374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.521    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1686     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 50400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000131 |
# |    n_updates        | 12574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1685     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 51200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00015  |
# |    n_updates        | 12774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1684     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.93e-05 |
# |    n_updates        | 12974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1683     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 52800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.35e-05 |
# |    n_updates        | 13174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1681     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 53600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.89e-05 |
# |    n_updates        | 13374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1678     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 54400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.3e-05  |
# |    n_updates        | 13574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1677     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 55200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.06e-05 |
# |    n_updates        | 13774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1676     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 56000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.53e-05 |
# |    n_updates        | 13974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1674     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 56800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3e-05  |
# |    n_updates        | 14174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1673     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 57600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98e-05 |
# |    n_updates        | 14374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1673     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 58400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.68e-06 |
# |    n_updates        | 14574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1673     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 59200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.98e-06 |
# |    n_updates        | 14774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.43     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1670     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.87e-06 |
# |    n_updates        | 14974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1669     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 60800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.51e-05 |
# |    n_updates        | 15174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1666     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 61600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000114 |
# |    n_updates        | 15374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1664     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 62400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000109 |
# |    n_updates        | 15574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1663     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 63200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61e-05 |
# |    n_updates        | 15774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1662     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.87e-06 |
# |    n_updates        | 15974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1660     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 64800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71e-06 |
# |    n_updates        | 16174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1658     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 65600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.82e-07 |
# |    n_updates        | 16374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1657     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 66400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.57e-07 |
# |    n_updates        | 16574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1657     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 67200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.78e-07 |
# |    n_updates        | 16774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1652     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 68000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.28e-07 |
# |    n_updates        | 16974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1646     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 68800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.92e-07 |
# |    n_updates        | 17174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.339    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1643     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 69600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.64e-07 |
# |    n_updates        | 17374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1641     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 70400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000192 |
# |    n_updates        | 17574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1639     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 71200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.23e-05 |
# |    n_updates        | 17774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1638     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.24e-05 |
# |    n_updates        | 17974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1635     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 72800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87e-05 |
# |    n_updates        | 18174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1633     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 73600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.9e-05  |
# |    n_updates        | 18374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1628     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 74400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18e-05 |
# |    n_updates        | 18574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1627     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 75200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.58e-06 |
# |    n_updates        | 18774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1626     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 76000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.06e-06 |
# |    n_updates        | 18974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1624     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 76800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.67e-06 |
# |    n_updates        | 19174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1623     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 77600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.01e-06 |
# |    n_updates        | 19374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.255    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1622     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 78400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.24e-07 |
# |    n_updates        | 19574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.248    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1618     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 79200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.41e-06 |
# |    n_updates        | 19774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.24     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1615     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 80000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09e-07 |
# |    n_updates        | 19974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1609     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 80800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000102 |
# |    n_updates        | 20174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1602     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 81600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000123 |
# |    n_updates        | 20374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.217    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1597     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 82400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.85e-05 |
# |    n_updates        | 20574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1594     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 83200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.08e-05 |
# |    n_updates        | 20774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1592     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 84000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.98e-05 |
# |    n_updates        | 20974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1592     |
# ...
# |    n_updates        | 242902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4864     |
# |    fps              | 1310     |
# |    time_elapsed     | 741      |
# |    total_timesteps  | 972509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58e-06 |
# |    n_updates        | 243102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4868     |
# |    fps              | 1310     |
# |    time_elapsed     | 742      |
# |    total_timesteps  | 973309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49e-05 |
# |    n_updates        | 243302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4872     |
# |    fps              | 1311     |
# |    time_elapsed     | 742      |
# |    total_timesteps  | 974109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01e-05 |
# |    n_updates        | 243502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4876     |
# |    fps              | 1311     |
# |    time_elapsed     | 743      |
# |    total_timesteps  | 974909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2e-05    |
# |    n_updates        | 243702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4880     |
# |    fps              | 1311     |
# |    time_elapsed     | 744      |
# |    total_timesteps  | 975709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.2e-06  |
# |    n_updates        | 243902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4884     |
# |    fps              | 1311     |
# |    time_elapsed     | 744      |
# |    total_timesteps  | 976509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09e-05 |
# |    n_updates        | 244102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4888     |
# |    fps              | 1311     |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 977309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01e-06 |
# |    n_updates        | 244302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4892     |
# |    fps              | 1311     |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 978109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.53e-06 |
# |    n_updates        | 244502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4896     |
# |    fps              | 1311     |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 978909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.44e-06 |
# |    n_updates        | 244702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4900     |
# |    fps              | 1311     |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 979709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14e-05 |
# |    n_updates        | 244902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4904     |
# |    fps              | 1311     |
# |    time_elapsed     | 747      |
# |    total_timesteps  | 980509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.39e-05 |
# |    n_updates        | 245102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4908     |
# |    fps              | 1312     |
# |    time_elapsed     | 747      |
# |    total_timesteps  | 981309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35e-05 |
# |    n_updates        | 245302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4912     |
# |    fps              | 1312     |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 982109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3e-06    |
# |    n_updates        | 245502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4916     |
# |    fps              | 1312     |
# |    time_elapsed     | 749      |
# |    total_timesteps  | 982909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35e-05 |
# |    n_updates        | 245702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4920     |
# |    fps              | 1311     |
# |    time_elapsed     | 749      |
# |    total_timesteps  | 983709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.72e-06 |
# |    n_updates        | 245902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4924     |
# |    fps              | 1311     |
# |    time_elapsed     | 750      |
# |    total_timesteps  | 984509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05e-06 |
# |    n_updates        | 246102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4928     |
# |    fps              | 1311     |
# |    time_elapsed     | 751      |
# |    total_timesteps  | 985309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.29e-06 |
# |    n_updates        | 246302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4932     |
# |    fps              | 1311     |
# |    time_elapsed     | 751      |
# |    total_timesteps  | 986109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.46e-06 |
# |    n_updates        | 246502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4936     |
# |    fps              | 1311     |
# |    time_elapsed     | 752      |
# |    total_timesteps  | 986909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.74e-06 |
# |    n_updates        | 246702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4940     |
# |    fps              | 1311     |
# |    time_elapsed     | 752      |
# |    total_timesteps  | 987709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.66e-05 |
# |    n_updates        | 246902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4944     |
# |    fps              | 1311     |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 988509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000194 |
# |    n_updates        | 247102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4948     |
# |    fps              | 1312     |
# |    time_elapsed     | 754      |
# |    total_timesteps  | 989309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.86e-06 |
# |    n_updates        | 247302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4952     |
# |    fps              | 1312     |
# |    time_elapsed     | 754      |
# |    total_timesteps  | 990109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00193  |
# |    n_updates        | 247502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4956     |
# |    fps              | 1312     |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 990909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94e-05 |
# |    n_updates        | 247702   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4960     |
# |    fps              | 1312     |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 991709   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.28e-06 |
# |    n_updates        | 247902   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4964     |
# |    fps              | 1312     |
# |    time_elapsed     | 756      |
# |    total_timesteps  | 992509   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26e-05 |
# |    n_updates        | 248102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4968     |
# |    fps              | 1312     |
# |    time_elapsed     | 756      |
# |    total_timesteps  | 993309   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75e-05 |
# |    n_updates        | 248302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4972     |
# |    fps              | 1312     |
# |    time_elapsed     | 757      |
# |    total_timesteps  | 994049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.2e-06  |
# |    n_updates        | 248487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4976     |
# |    fps              | 1312     |
# |    time_elapsed     | 757      |
# |    total_timesteps  | 994849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.78e-06 |
# |    n_updates        | 248687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4980     |
# |    fps              | 1312     |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 995649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.43e-06 |
# |    n_updates        | 248887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4984     |
# |    fps              | 1313     |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 996449   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.34e-05 |
# |    n_updates        | 249087   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4988     |
# |    fps              | 1313     |
# |    time_elapsed     | 759      |
# |    total_timesteps  | 997249   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.44e-06 |
# |    n_updates        | 249287   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4992     |
# |    fps              | 1313     |
# |    time_elapsed     | 760      |
# |    total_timesteps  | 998049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.46e-05 |
# |    n_updates        | 249487   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4996     |
# |    fps              | 1313     |
# |    time_elapsed     | 760      |
# |    total_timesteps  | 998849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.06e-06 |
# |    n_updates        | 249687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5000     |
# |    fps              | 1312     |
# |    time_elapsed     | 761      |
# |    total_timesteps  | 999649   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26e-05 |
# |    n_updates        | 249887   |
# ----------------------------------

# %%
DQN_Path = os.path.join('Saved Model', 'DQN_1M')
model.save(DQN_Path)

# %%
test_env = gym.make("MountainCar-v0", render_mode='human')
episodes = 5
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncate = False
    score = 0

    while not done and not truncate:
        action, _ = model.predict(obs)
        obs, reward, done, truncate, info = test_env.step(action)
        score += reward
    print(f"Episode:{episode+1} Score:{score}")
test_env.close()
# Out:
# Episode:1 Score:-200.0
# Episode:2 Score:-200.0
# Episode:3 Score:-200.0
# Episode:4 Score:-200.0
# Episode:5 Score:-200.0

# %%
from stable_baselines3 import A2C

# %%
model = A2C('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=500000)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | -0.049   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -2.59    |
# |    value_loss         | 8.06     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 770      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.0897   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -2.35    |
# |    value_loss         | 5.94     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 795      |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.00278 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.2     |
# |    value_loss         | 5.73     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 814      |
# |    iterations         | 400      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.0161   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -2.02    |
# |    value_loss         | 4.94     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 834      |
# |    iterations         | 500      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.00962 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -1.58    |
# |    value_loss         | 4.38     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 839      |
# |    iterations         | 600      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -0.00164 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -1.95    |
# |    value_loss         | 3.75     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 844      |
# |    iterations         | 700      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.000909 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -1.88    |
# |    value_loss         | 3.18     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 838      |
# |    iterations         | 800      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.00056  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -1.65    |
# |    value_loss         | 2.68     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 827       |
# |    iterations         | 900       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -8.58e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -1.51     |
# |    value_loss         | 2.21      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 836      |
# |    iterations         | 1000     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.000156 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -1.41    |
# |    value_loss         | 1.79     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 843       |
# |    iterations         | 1100      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -0.000457 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -1.23     |
# |    value_loss         | 1.42      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 848      |
# |    iterations         | 1200     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.00022  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -1.06    |
# |    value_loss         | 1.09     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 1300      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.999    |
# |    explained_variance | -0.000188 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -0.488    |
# |    value_loss         | 0.799     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 861       |
# |    iterations         | 1400      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -4.11e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.699    |
# |    value_loss         | 0.555     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 863       |
# |    iterations         | 1500      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -4.28e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.579    |
# |    value_loss         | 0.356     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 1600     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.000114 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.463   |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 871      |
# |    iterations         | 1700     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.231   |
# |    value_loss         | 0.0896   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 872       |
# |    iterations         | 1800      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -0.000339 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -0.144    |
# |    value_loss         | 0.0227    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 875       |
# |    iterations         | 1900      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | -0.000629 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -0.0228   |
# |    value_loss         | 0.000596  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 878       |
# |    iterations         | 2000      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 0.0853    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000969 |
# |    value_loss         | 9.1e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 882       |
# |    iterations         | 2100      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -2.61e-05 |
# |    value_loss         | 8.61e-10  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 876      |
# |    iterations         | 2200     |
# |    time_elapsed       | 12       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 1.3e-05  |
# |    value_loss         | 3.14e-10 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 868      |
# |    iterations         | 2300     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.32     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 1.07e-05 |
# |    value_loss         | 1.63e-10 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 864      |
# |    iterations         | 2400     |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.742    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 4.77e-05 |
# |    value_loss         | 1.97e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 864      |
# |    iterations         | 2500     |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0       |
# |    value_loss         | 0        |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 863      |
# |    iterations         | 2600     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -7e-05   |
# |    value_loss         | 4.76e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 861      |
# |    iterations         | 2700     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0       |
# |    value_loss         | 0        |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 857      |
# |    iterations         | 2800     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 5.84e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.00052 |
# |    value_loss         | 2.24e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 2900      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | 0.000375  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.000561 |
# |    value_loss         | 5.5e-07   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 857      |
# |    iterations         | 3000     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.000147 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00101 |
# |    value_loss         | 8.24e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 857      |
# |    iterations         | 3100     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | -0.0423  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.00108 |
# |    value_loss         | 1.55e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 3200      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | 4.99e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -0.000798 |
# |    value_loss         | 1.05e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 3300      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -0.0981   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -0.000806 |
# |    value_loss         | 6.88e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 3400      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | -0.0438   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.000504 |
# |    value_loss         | 2.34e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 858       |
# |    iterations         | 3500      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -1.02     |
# |    explained_variance | 0.0511    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.000366 |
# |    value_loss         | 1.48e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 860       |
# |    iterations         | 3600      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | -0.0219   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -0.000296 |
# |    value_loss         | 2.3e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 861       |
# |    iterations         | 3700      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -0.959    |
# |    explained_variance | 0.0162    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -0.000538 |
# |    value_loss         | 3.72e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 862      |
# |    iterations         | 3800     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.988   |
# |    explained_variance | 1.92e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.00067 |
# |    value_loss         | 6.77e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 3900      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.947    |
# |    explained_variance | 0.0147    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -0.000986 |
# |    value_loss         | 1.1e-06   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 865       |
# |    iterations         | 4000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.901    |
# |    explained_variance | 0.000131  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -0.000518 |
# |    value_loss         | 8.98e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 4100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -0.883    |
# |    explained_variance | 5.25e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.000313 |
# |    value_loss         | 2.41e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 868       |
# |    iterations         | 4200      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.771    |
# |    explained_variance | 0.0602    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -0.000139 |
# |    value_loss         | 2.31e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 867       |
# |    iterations         | 4300      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -0.895    |
# |    explained_variance | 2.52e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -0.000671 |
# |    value_loss         | 5.21e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 866       |
# |    iterations         | 4400      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.857    |
# |    explained_variance | -0.0519   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -0.000513 |
# |    value_loss         | 6.69e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 863       |
# |    iterations         | 4500      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -0.915    |
# |    explained_variance | 0.017     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -0.000641 |
# |    value_loss         | 3.52e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 864       |
# |    iterations         | 4600      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -0.734    |
# |    explained_variance | -0.0446   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -0.000862 |
# |    value_loss         | 5e-07     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 861       |
# |    iterations         | 4700      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -0.916    |
# |    explained_variance | 0.018     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -0.000851 |
# |    value_loss         | 7.09e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 858       |
# |    iterations         | 4800      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.838    |
# |    explained_variance | 0.029     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -0.000361 |
# |    value_loss         | 7.38e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 860       |
# |    iterations         | 4900      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -0.959    |
# |    explained_variance | -0.0129   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -0.000836 |
# |    value_loss         | 6.05e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 5000      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -0.934    |
# |    explained_variance | -0.0346   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -0.000933 |
# |    value_loss         | 5.83e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 855      |
# |    iterations         | 5100     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.933   |
# |    explained_variance | 3.15e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.00041 |
# |    value_loss         | 4.17e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 5200      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -0.97     |
# |    explained_variance | 0.0289    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -0.000747 |
# |    value_loss         | 7.46e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 5300      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -0.868    |
# |    explained_variance | 2.06e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -0.000523 |
# |    value_loss         | 6.45e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 5400      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -0.865    |
# |    explained_variance | -0.101    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.000473 |
# |    value_loss         | 6.38e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 856      |
# |    iterations         | 5500     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.88    |
# |    explained_variance | -0.0117  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.00092 |
# |    value_loss         | 7.71e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 5600      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.732    |
# |    explained_variance | 0.0299    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -0.000216 |
# |    value_loss         | 7.09e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 855      |
# |    iterations         | 5700     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.878   |
# |    explained_variance | 0.107    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.00043 |
# |    value_loss         | 4.99e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 5800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -0.864    |
# |    explained_variance | 0.0315    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -0.000391 |
# |    value_loss         | 4.01e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 856      |
# |    iterations         | 5900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.931   |
# |    explained_variance | -0.0494  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.00068 |
# |    value_loss         | 2.81e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 6000      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -0.837    |
# |    explained_variance | 0.000466  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -0.000228 |
# |    value_loss         | 4.51e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 6100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -0.703    |
# |    explained_variance | 1.92e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -0.000197 |
# |    value_loss         | 6.87e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 858       |
# |    iterations         | 6200      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -0.767    |
# |    explained_variance | 2.91e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -0.000822 |
# |    value_loss         | 4.51e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 6300      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.802    |
# |    explained_variance | 0.0133    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -0.000757 |
# |    value_loss         | 5.78e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 857      |
# |    iterations         | 6400     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.839   |
# |    explained_variance | 1.71e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0012  |
# |    value_loss         | 7.6e-07  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 857       |
# |    iterations         | 6500      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -0.987    |
# |    explained_variance | 0.00029   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -0.000536 |
# |    value_loss         | 7.2e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 6600      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -0.953    |
# |    explained_variance | 0.077     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -0.000908 |
# |    value_loss         | 3.85e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 856       |
# |    iterations         | 6700      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -0.96     |
# |    explained_variance | -0.0172   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -0.000294 |
# |    value_loss         | 3.7e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 6800      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.999    |
# |    explained_variance | 3.95e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -0.000494 |
# |    value_loss         | 3.24e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 6900      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | 0.0306    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -0.000381 |
# |    value_loss         | 2.44e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 855       |
# |    iterations         | 7000      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -1.01     |
# |    explained_variance | 0.0113    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -0.000822 |
# |    value_loss         | 8.04e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 7100      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -0.0477   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -0.000707 |
# |    value_loss         | 7.88e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 7200      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | 0.0864    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -0.000502 |
# |    value_loss         | 4.51e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 7300      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -1        |
# |    explained_variance | 0.0162    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -0.000716 |
# |    value_loss         | 8.9e-07   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 855      |
# |    iterations         | 7400     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.00361  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.00108 |
# |    value_loss         | 1.37e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 7500      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -0.0225   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0.000769 |
# |    value_loss         | 4.54e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 854       |
# |    iterations         | 7600      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | 0.178     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -0.000815 |
# |    value_loss         | 5.39e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 853       |
# |    iterations         | 7700      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -0.0207   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -0.000792 |
# |    value_loss         | 5.85e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 852       |
# |    iterations         | 7800      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | 0.18      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -0.000634 |
# |    value_loss         | 3.66e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 851       |
# |    iterations         | 7900      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | 0.000466  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -0.000637 |
# |    value_loss         | 4.51e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8000      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -0.407    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -0.000808 |
# |    value_loss         | 7.85e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8100      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | -0.0728   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -0.000711 |
# |    value_loss         | 4.29e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8200      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | 0.0207    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | -0.000787 |
# |    value_loss         | 5.43e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8300      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -0.0359   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -0.000577 |
# |    value_loss         | 3.4e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8400      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -1.03     |
# |    explained_variance | 3.62e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -0.000515 |
# |    value_loss         | 3.44e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 851       |
# |    iterations         | 8500      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -0.112    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -0.000907 |
# |    value_loss         | 6.16e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 8600     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 43000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.0406   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.00067 |
# |    value_loss         | 5.38e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8700      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -0.19     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -0.000663 |
# |    value_loss         | 4.51e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 850      |
# |    iterations         | 8800     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | 0.101    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | -0.00073 |
# |    value_loss         | 4.27e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 850       |
# |    iterations         | 8900      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | 0.0357    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -0.000789 |
# |    value_loss         | 9.6e-07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 851       |
# |    iterations         | 9000      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | 0.104     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -0.000645 |
# |    value_loss         | 4.12e-07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 849       |
# |    iterations         | 9100      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | -0.0168   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | -0.000541 |
# |    value_loss         | 3.93e-07  |
# ...
# |    fps                | 878      |
# |    iterations         | 97000    |
# |    time_elapsed       | 551      |
# |    total_timesteps    | 485000   |
# | train/                |          |
# |    entropy_loss       | -0.101   |
# |    explained_variance | 0.0483   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 96999    |
# |    policy_loss        | 1.09e-05 |
# |    value_loss         | 3.72e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97100    |
# |    time_elapsed       | 552      |
# |    total_timesteps    | 485500   |
# | train/                |          |
# |    entropy_loss       | -0.084   |
# |    explained_variance | -0.102   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97099    |
# |    policy_loss        | 9.2e-06  |
# |    value_loss         | 4.19e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97200    |
# |    time_elapsed       | 552      |
# |    total_timesteps    | 486000   |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0.165    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97199    |
# |    policy_loss        | 0.000664 |
# |    value_loss         | 5.39e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97300    |
# |    time_elapsed       | 553      |
# |    total_timesteps    | 486500   |
# | train/                |          |
# |    entropy_loss       | -0.0687  |
# |    explained_variance | -0.371   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97299    |
# |    policy_loss        | 4.49e-06 |
# |    value_loss         | 1.75e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97400    |
# |    time_elapsed       | 553      |
# |    total_timesteps    | 487000   |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | -16.3    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97399    |
# |    policy_loss        | 6.56e-06 |
# |    value_loss         | 5.58e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97500    |
# |    time_elapsed       | 554      |
# |    total_timesteps    | 487500   |
# | train/                |          |
# |    entropy_loss       | -0.0658  |
# |    explained_variance | -0.0867  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97499    |
# |    policy_loss        | 9.19e-06 |
# |    value_loss         | 7.82e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97600    |
# |    time_elapsed       | 555      |
# |    total_timesteps    | 488000   |
# | train/                |          |
# |    entropy_loss       | -0.0923  |
# |    explained_variance | 0.0726   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97599    |
# |    policy_loss        | 1.09e-05 |
# |    value_loss         | 4.57e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97700    |
# |    time_elapsed       | 555      |
# |    total_timesteps    | 488500   |
# | train/                |          |
# |    entropy_loss       | -0.0716  |
# |    explained_variance | -0.0117  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97699    |
# |    policy_loss        | 1.04e-05 |
# |    value_loss         | 7.54e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97800    |
# |    time_elapsed       | 556      |
# |    total_timesteps    | 489000   |
# | train/                |          |
# |    entropy_loss       | -0.0645  |
# |    explained_variance | 5.54e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97799    |
# |    policy_loss        | 1e-05    |
# |    value_loss         | 9.54e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 97900    |
# |    time_elapsed       | 556      |
# |    total_timesteps    | 489500   |
# | train/                |          |
# |    entropy_loss       | -0.0499  |
# |    explained_variance | -0.0181  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97899    |
# |    policy_loss        | 6.43e-06 |
# |    value_loss         | 7.3e-07  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98000    |
# |    time_elapsed       | 557      |
# |    total_timesteps    | 490000   |
# | train/                |          |
# |    entropy_loss       | -0.106   |
# |    explained_variance | -0.068   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97999    |
# |    policy_loss        | 1.42e-05 |
# |    value_loss         | 5.77e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98100    |
# |    time_elapsed       | 557      |
# |    total_timesteps    | 490500   |
# | train/                |          |
# |    entropy_loss       | -0.0444  |
# |    explained_variance | -0.0784  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98099    |
# |    policy_loss        | 4.41e-06 |
# |    value_loss         | 4.71e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 879       |
# |    iterations         | 98200     |
# |    time_elapsed       | 558       |
# |    total_timesteps    | 491000    |
# | train/                |           |
# |    entropy_loss       | -0.0825   |
# |    explained_variance | -0.000714 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 98199     |
# |    policy_loss        | 7.09e-06  |
# |    value_loss         | 2.69e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98300    |
# |    time_elapsed       | 558      |
# |    total_timesteps    | 491500   |
# | train/                |          |
# |    entropy_loss       | -0.0517  |
# |    explained_variance | -0.0517  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98299    |
# |    policy_loss        | 4.82e-06 |
# |    value_loss         | 3.8e-07  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98400    |
# |    time_elapsed       | 559      |
# |    total_timesteps    | 492000   |
# | train/                |          |
# |    entropy_loss       | -0.0691  |
# |    explained_variance | 0.0153   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98399    |
# |    policy_loss        | 7.38e-06 |
# |    value_loss         | 4.29e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98500    |
# |    time_elapsed       | 560      |
# |    total_timesteps    | 492500   |
# | train/                |          |
# |    entropy_loss       | -0.0626  |
# |    explained_variance | -0.105   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98499    |
# |    policy_loss        | 5.78e-06 |
# |    value_loss         | 3.43e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98600    |
# |    time_elapsed       | 560      |
# |    total_timesteps    | 493000   |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | -0.052   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98599    |
# |    policy_loss        | 9.94e-06 |
# |    value_loss         | 3.58e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98700    |
# |    time_elapsed       | 561      |
# |    total_timesteps    | 493500   |
# | train/                |          |
# |    entropy_loss       | -0.062   |
# |    explained_variance | -0.124   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98699    |
# |    policy_loss        | 6.15e-06 |
# |    value_loss         | 4.06e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98800    |
# |    time_elapsed       | 561      |
# |    total_timesteps    | 494000   |
# | train/                |          |
# |    entropy_loss       | -0.078   |
# |    explained_variance | 0.0434   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98799    |
# |    policy_loss        | 6e-06    |
# |    value_loss         | 2.12e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 98900    |
# |    time_elapsed       | 562      |
# |    total_timesteps    | 494500   |
# | train/                |          |
# |    entropy_loss       | -0.0763  |
# |    explained_variance | -0.0521  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98899    |
# |    policy_loss        | 9.13e-06 |
# |    value_loss         | 5.18e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99000    |
# |    time_elapsed       | 562      |
# |    total_timesteps    | 495000   |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0.0849   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98999    |
# |    policy_loss        | 1.83e-05 |
# |    value_loss         | 6.21e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99100    |
# |    time_elapsed       | 563      |
# |    total_timesteps    | 495500   |
# | train/                |          |
# |    entropy_loss       | -0.105   |
# |    explained_variance | -0.0501  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99099    |
# |    policy_loss        | 1.6e-05  |
# |    value_loss         | 7.18e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99200    |
# |    time_elapsed       | 563      |
# |    total_timesteps    | 496000   |
# | train/                |          |
# |    entropy_loss       | -0.166   |
# |    explained_variance | 0.00755  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99199    |
# |    policy_loss        | 2.23e-05 |
# |    value_loss         | 4.32e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99300    |
# |    time_elapsed       | 564      |
# |    total_timesteps    | 496500   |
# | train/                |          |
# |    entropy_loss       | -0.0998  |
# |    explained_variance | -0.133   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99299    |
# |    policy_loss        | 1.14e-05 |
# |    value_loss         | 4.13e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99400    |
# |    time_elapsed       | 565      |
# |    total_timesteps    | 497000   |
# | train/                |          |
# |    entropy_loss       | -0.0721  |
# |    explained_variance | 0.000533 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99399    |
# |    policy_loss        | 7.39e-06 |
# |    value_loss         | 3.85e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99500    |
# |    time_elapsed       | 565      |
# |    total_timesteps    | 497500   |
# | train/                |          |
# |    entropy_loss       | -0.0656  |
# |    explained_variance | -0.0222  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99499    |
# |    policy_loss        | 7.48e-06 |
# |    value_loss         | 5.03e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99600    |
# |    time_elapsed       | 566      |
# |    total_timesteps    | 498000   |
# | train/                |          |
# |    entropy_loss       | -0.0876  |
# |    explained_variance | 0.000125 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99599    |
# |    policy_loss        | 1.47e-05 |
# |    value_loss         | 9.46e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99700    |
# |    time_elapsed       | 566      |
# |    total_timesteps    | 498500   |
# | train/                |          |
# |    entropy_loss       | -0.104   |
# |    explained_variance | -0.0334  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99699    |
# |    policy_loss        | 1.49e-05 |
# |    value_loss         | 6.25e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99800    |
# |    time_elapsed       | 567      |
# |    total_timesteps    | 499000   |
# | train/                |          |
# |    entropy_loss       | -0.119   |
# |    explained_variance | 0.128    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99799    |
# |    policy_loss        | 1.45e-05 |
# |    value_loss         | 4.32e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 99900    |
# |    time_elapsed       | 567      |
# |    total_timesteps    | 499500   |
# | train/                |          |
# |    entropy_loss       | -0.0859  |
# |    explained_variance | -0.137   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99899    |
# |    policy_loss        | 9.56e-06 |
# |    value_loss         | 4.51e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 879      |
# |    iterations         | 100000   |
# |    time_elapsed       | 568      |
# |    total_timesteps    | 500000   |
# | train/                |          |
# |    entropy_loss       | -0.0763  |
# |    explained_variance | 0.0494   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99999    |
# |    policy_loss        | 1.14e-05 |
# |    value_loss         | 8.01e-07 |
# ------------------------------------

# %%
A2C_path = os.path.join('Saved Model', 'A2C_5L')
model.save(A2C_path)

# %%
test_env = gym.make("MountainCar-v0", render_mode='human')
episodes = 10
for episode in range(episodes):
    obs, _ = test_env.reset()
    done = False
    truncate = False
    score = 0

    while not done and not truncate:
        action, _ = model.predict(obs)
        obs, reward, done, truncate, info = test_env.step(action)
        score += reward
    print(f"Episode:{episode+1} Score:{score}")
test_env.close()
# Out:
# Episode:1 Score:-200.0
# Episode:2 Score:-200.0
# Episode:3 Score:-200.0
# Episode:4 Score:-200.0
# Episode:5 Score:-200.0
# Episode:6 Score:-200.0
# Episode:7 Score:-200.0
# Episode:8 Score:-200.0
# Episode:9 Score:-200.0
# Episode:10 Score:-200.0
